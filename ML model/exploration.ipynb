# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns
import sklearn
import glob
import os
from os import path

# %%
path = 'data_zip/archive'
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
for f in csv_files:
      
    # read the csv file
    df = pd.read_csv(f)
      
    # print the location, filename, length
    print('Location:', f)
    print('File Name:', f.split("\\")[-1])
    print(f'length of df = {len(df)}')
      
    # print the content
    print('Content:')
    display(df.head(2))

    print()
# Out:
# Location: data_zip/archive/season-1314.csv
# File Name: data_zip/archive/season-1314.csv
# length of df = 380
# Content:
#   Div      Date   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 0  E0  17/08/13    Arsenal  Aston Villa     1     3   A     1     1   D  ...
# 1  E0  17/08/13  Liverpool        Stoke     1     0   H     1     0   H  ...
#
#   BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD   PSCA
# 0     2.37   NaN    NaN      NaN      NaN      NaN      NaN  1.44  5.00   8.05
# 1     2.02   NaN    NaN      NaN      NaN      NaN      NaN  1.42  4.62  10.19
#
# [2 rows x 68 columns]
# Location: data_zip/archive/season-1112.csv
# File Name: data_zip/archive/season-1112.csv
# length of df = 380
# Content:
#   Div      Date   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 0  E0  13/08/11  Blackburn       Wolves     1     2   A     1     1   D  ...
# 1  E0  13/08/11     Fulham  Aston Villa     0     0   D     0     0   D  ...
#
# ...

# %%
len(csv_files)
# Out:
# 10

# %%
#concatenate files to one file
li = []

for filename in csv_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

epl= pd.concat(li, axis=0, ignore_index=True)
epl
# Out:
#      Div      Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0     E0  17/08/13      Arsenal  Aston Villa   1.0   3.0   A   1.0   1.0   D
# 1     E0  17/08/13    Liverpool        Stoke   1.0   0.0   H   1.0   0.0   H
# 2     E0  17/08/13      Norwich      Everton   2.0   2.0   D   0.0   0.0   D
# 3     E0  17/08/13   Sunderland       Fulham   0.0   1.0   A   0.0   0.0   D
# 4     E0  17/08/13      Swansea   Man United   1.0   4.0   A   0.0   2.0   A
# ...   ..       ...          ...          ...   ...   ...  ..   ...   ...  ..
# 3796  E0  13/05/18    Newcastle      Chelsea   3.0   0.0   H   1.0   0.0   H
# 3797  E0  13/05/18  Southampton     Man City   0.0   1.0   A   0.0   0.0   D
# 3798  E0  13/05/18      Swansea        Stoke   1.0   2.0   A   1.0   2.0   A
# 3799  E0  13/05/18    Tottenham    Leicester   5.0   4.0   H   1.0   2.0   A
# 3800  E0  13/05/18     West Ham      Everton   3.0   1.0   H   1.0   0.0   H
#
# ...

# %%
epl.columns[:50]
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'PSH', 'PSD', 'PSA',
#        'WHH', 'WHD', 'WHA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'Bb1X2',
#        'BbMxH', 'BbAvH'],
#       dtype='object')

# %%
epl.columns[50:]
# Out:
# Index(['BbMxD', 'BbAvD', 'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5',
#        'BbMx<2.5', 'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH',
#        'BbMxAHA', 'BbAvAHA', 'PSCH', 'PSCD', 'PSCA', 'GBH', 'GBD', 'GBA',
#        'SBH', 'SBD', 'SBA', 'BSH', 'BSD', 'BSA'],
#       dtype='object')

# %%
#goals, shots, shots on target, possesion, tackles, fouls, yellow cards, red cards, corners
if len(epl.columns) > 50: 
    epl= epl.iloc[:, 1:23]
epl.head()
# Out:
#        Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  17/08/13     Arsenal  Aston Villa   1.0   3.0   A   1.0   1.0   D
# 1  17/08/13   Liverpool        Stoke   1.0   0.0   H   1.0   0.0   H
# 2  17/08/13     Norwich      Everton   2.0   2.0   D   0.0   0.0   D
# 3  17/08/13  Sunderland       Fulham   0.0   1.0   A   0.0   0.0   D
# 4  17/08/13     Swansea   Man United   1.0   4.0   A   0.0   2.0   A
#
#        Referee  ...   HST  AST    HF    AF    HC   AC   HY   AY   HR   AR
# 0     A Taylor  ...   4.0  4.0  15.0  18.0   4.0  3.0  4.0  5.0  1.0  0.0
# 1   M Atkinson  ...  11.0  4.0  11.0  11.0  12.0  6.0  1.0  1.0  0.0  0.0
# 2     M Oliver  ...   2.0  6.0  13.0  10.0   6.0  8.0  2.0  0.0  0.0  0.0
# 3  N Swarbrick  ...   3.0  1.0  14.0  14.0   6.0  1.0  0.0  3.0  0.0  0.0
# 4       P Dowd  ...   6.0  7.0  13.0  10.0   7.0  4.0  1.0  3.0  0.0  0.0
#
# [5 rows x 22 columns]

# %%
#drop referee, HomeTeam, AwayTeam columns
if 'HomeTeam' in epl.columns:
    epl.drop(['HomeTeam'], axis = 1, inplace = True)
if 'AwayTeam' in epl.columns:
    epl.drop(['AwayTeam'], axis = 1, inplace = True)
if 'Referee' in epl.columns:
    epl.drop(['Referee'], axis = 1, inplace = True)
epl.head()
# Out:
#        Date  FTHG  FTAG FTR  HTHG  HTAG HTR    HS    AS   HST  AST    HF  \
# 0  17/08/13   1.0   3.0   A   1.0   1.0   D  16.0   9.0   4.0  4.0  15.0
# 1  17/08/13   1.0   0.0   H   1.0   0.0   H  26.0  10.0  11.0  4.0  11.0
# 2  17/08/13   2.0   2.0   D   0.0   0.0   D   8.0  19.0   2.0  6.0  13.0
# 3  17/08/13   0.0   1.0   A   0.0   0.0   D  20.0   5.0   3.0  1.0  14.0
# 4  17/08/13   1.0   4.0   A   0.0   2.0   A  17.0  15.0   6.0  7.0  13.0
#
#      AF    HC   AC   HY   AY   HR   AR
# 0  18.0   4.0  3.0  4.0  5.0  1.0  0.0
# 1  11.0  12.0  6.0  1.0  1.0  0.0  0.0
# 2  10.0   6.0  8.0  2.0  0.0  0.0  0.0
# 3  14.0   6.0  1.0  0.0  3.0  0.0  0.0
# 4  10.0   7.0  4.0  1.0  3.0  0.0  0.0

# %%
sns.scatterplot(y = 'FTHG', x = 'HST', data = epl, alpha = .08)
# Out:
# <AxesSubplot:xlabel='HST', ylabel='FTHG'>

# %%
sns.scatterplot(y = 'FTHG', x = 'AST', data = epl, alpha = .1)
# Out:
# <AxesSubplot:xlabel='AST', ylabel='FTHG'>

# %%
sns.barplot(y = 'FTR', x = 'FTHG', data = epl)
# Out:
# <AxesSubplot:xlabel='FTHG', ylabel='FTR'>

# %%
sns.barplot(y = 'FTR', x = 'HR', data = epl)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='FTR'>

# %%
sns.barplot(y = 'FTR', x = 'HS', data = epl)
# Out:
# <AxesSubplot:xlabel='HS', ylabel='FTR'>

# %%
sns.barplot(y = 'FTR', x = 'HST', data = epl)
# Out:
# <AxesSubplot:xlabel='HST', ylabel='FTR'>

# %%
epl.head()
# Out:
#        Date  FTHG  FTAG FTR  HTHG  HTAG HTR    HS    AS   HST  AST    HF  \
# 0  17/08/13   1.0   3.0   A   1.0   1.0   D  16.0   9.0   4.0  4.0  15.0
# 1  17/08/13   1.0   0.0   H   1.0   0.0   H  26.0  10.0  11.0  4.0  11.0
# 2  17/08/13   2.0   2.0   D   0.0   0.0   D   8.0  19.0   2.0  6.0  13.0
# 3  17/08/13   0.0   1.0   A   0.0   0.0   D  20.0   5.0   3.0  1.0  14.0
# 4  17/08/13   1.0   4.0   A   0.0   2.0   A  17.0  15.0   6.0  7.0  13.0
#
#      AF    HC   AC   HY   AY   HR   AR
# 0  18.0   4.0  3.0  4.0  5.0  1.0  0.0
# 1  11.0  12.0  6.0  1.0  1.0  0.0  0.0
# 2  10.0   6.0  8.0  2.0  0.0  0.0  0.0
# 3  14.0   6.0  1.0  0.0  3.0  0.0  0.0
# 4  10.0   7.0  4.0  1.0  3.0  0.0  0.0

# %%
#shuffle df rows and eliminate Halftime metrics
epl = epl.sample(frac=1)
epl = epl[['FTHG', 'FTAG', 'FTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']]
epl
# Out:
#       FTHG  FTAG FTR    HS    AS   HST  AST    HF    AF   HC   AC   HY   AY  \
# 1080   4.0   1.0   H  14.0  10.0   6.0  3.0  14.0  14.0  6.0  3.0  0.0  2.0
# 451    4.0   1.0   H  15.0   8.0  10.0  6.0  10.0   6.0  5.0  1.0  1.0  1.0
# 2270   0.0   1.0   A  10.0  10.0   5.0  6.0  12.0  14.0  9.0  7.0  0.0  3.0
# 2186   1.0   2.0   A   7.0  18.0   2.0  9.0  16.0  13.0  2.0  8.0  2.0  2.0
# 3130   3.0   1.0   H  19.0   8.0   6.0  2.0  10.0  10.0  6.0  4.0  2.0  2.0
# ...    ...   ...  ..   ...   ...   ...  ...   ...   ...  ...  ...  ...  ...
# 27     1.0   0.0   H  12.0  14.0   5.0  4.0  15.0  14.0  3.0  6.0  2.0  2.0
# 1533   2.0   2.0   D   8.0  13.0   2.0  3.0  10.0  18.0  3.0  3.0  1.0  4.0
# 3007   1.0   1.0   D   8.0   7.0   1.0  2.0  10.0  16.0  0.0  2.0  3.0  3.0
# 1384   1.0   0.0   H   7.0   6.0   4.0  1.0  10.0  14.0  5.0  5.0  1.0  3.0
# 2095   5.0   0.0   H  23.0  11.0  16.0  6.0   6.0  11.0  7.0  3.0  0.0  1.0
#
#        HR   AR
# 1080  0.0  0.0
# 451   0.0  0.0
# ...

# %% [markdown]
# # Models

# %% [markdown]
# I want to predict:
# 1) FTHG - full time home goals
# 2) FTAG - full time away goals
# 3) FTR - full time result (A, H, D)
#
# So, the goal is to create 3 functions where each takes in the box score and gives:
# 1) Expected goals Home Team
# 2) Expected goals away team
# 3) Home win percentage, away win percentage, draw percentage

# %% [markdown]
# ## 1. Expected Goals Home team

# %%
epl.describe()
# Out:
#               FTHG         FTAG           HS           AS          HST  \
# count  3800.000000  3800.000000  3800.000000  3800.000000  3800.000000
# mean      1.570526     1.180000    14.181316    11.229211     6.014211
# std       1.322363     1.160788     5.514299     4.687029     3.443571
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000    10.000000     8.000000     3.000000
# 50%       1.000000     1.000000    14.000000    11.000000     5.000000
# 75%       2.000000     2.000000    17.000000    14.000000     8.000000
# max       9.000000     7.000000    43.000000    30.000000    24.000000
#
#                AST           HF           AF           HC           AC  \
# count  3800.000000  3800.000000  3800.000000  3800.000000  3800.000000
# mean      4.763947    10.618684    11.133421     6.028158     4.774211
# std       2.891895     3.397368     3.580877     3.131663     2.737833
# ...

# %%
epl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3800 entries, 1080 to 2095
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FTHG    3800 non-null   float64
#  1   FTAG    3800 non-null   float64
#  2   FTR     3800 non-null   object
#  3   HS      3800 non-null   float64
#  4   AS      3800 non-null   float64
#  5   HST     3800 non-null   float64
#  6   AST     3800 non-null   float64
#  7   HF      3800 non-null   float64
#  8   AF      3800 non-null   float64
#  9   HC      3800 non-null   float64
#  10  AC      3800 non-null   float64
#  11  HY      3800 non-null   float64
#  12  AY      3800 non-null   float64
#  13  HR      3800 non-null   float64
#  14  AR      3800 non-null   float64
# dtypes: float64(14), object(1)
# memory usage: 475.0+ KB

# %%
corr_matrix = epl.corr()
corr_matrix['FTHG'].sort_values(ascending = False)
# Out:
# FTHG    1.000000
# HST     0.446156
# HS      0.288352
# AR      0.072354
# HC      0.057204
# AY     -0.011191
# AF     -0.045542
# HF     -0.059840
# AC     -0.080303
# HR     -0.080648
# FTAG   -0.084583
# AST    -0.100444
# HY     -0.111800
# AS     -0.152125
# Name: FTHG, dtype: float64

# %%
epl = epl.dropna(axis=0)
epl
# Out:
#       FTHG  FTAG FTR    HS    AS   HST  AST    HF    AF   HC   AC   HY   AY  \
# 1080   4.0   1.0   H  14.0  10.0   6.0  3.0  14.0  14.0  6.0  3.0  0.0  2.0
# 451    4.0   1.0   H  15.0   8.0  10.0  6.0  10.0   6.0  5.0  1.0  1.0  1.0
# 2270   0.0   1.0   A  10.0  10.0   5.0  6.0  12.0  14.0  9.0  7.0  0.0  3.0
# 2186   1.0   2.0   A   7.0  18.0   2.0  9.0  16.0  13.0  2.0  8.0  2.0  2.0
# 3130   3.0   1.0   H  19.0   8.0   6.0  2.0  10.0  10.0  6.0  4.0  2.0  2.0
# ...    ...   ...  ..   ...   ...   ...  ...   ...   ...  ...  ...  ...  ...
# 27     1.0   0.0   H  12.0  14.0   5.0  4.0  15.0  14.0  3.0  6.0  2.0  2.0
# 1533   2.0   2.0   D   8.0  13.0   2.0  3.0  10.0  18.0  3.0  3.0  1.0  4.0
# 3007   1.0   1.0   D   8.0   7.0   1.0  2.0  10.0  16.0  0.0  2.0  3.0  3.0
# 1384   1.0   0.0   H   7.0   6.0   4.0  1.0  10.0  14.0  5.0  5.0  1.0  3.0
# 2095   5.0   0.0   H  23.0  11.0  16.0  6.0   6.0  11.0  7.0  3.0  0.0  1.0
#
#        HR   AR
# 1080  0.0  0.0
# 451   0.0  0.0
# ...

# %%
y = epl.FTHG
epl_features = ['HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']
X = epl[epl_features]
y = y.astype('float32')
X = X.astype('float32')

# %%
from sklearn.model_selection import train_test_split

train_X, val_X, train_y, val_y = train_test_split(X, y,random_state = 0)

# %% [markdown]
# ### 1.1: Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
forest_model = RandomForestRegressor(n_estimators = 100, random_state=1)
forest_model.fit(train_X, train_y)

HG_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, HG_preds))
# Out:
# 0.906021052631579

# %%
for feature in zip(epl_features, forest_model.feature_importances_):
    print(feature)
# Out:
# ('HS', 0.09399702117041835)
# ('AS', 0.09712360493235526)
# ('HST', 0.25175735150134604)
# ('AST', 0.08191165221236224)
# ('HF', 0.09285058700361032)
# ('AF', 0.09260853843657989)
# ('HC', 0.09278791382717796)
# ('AC', 0.07371684548327202)
# ('HY', 0.051446187329608574)
# ('AY', 0.04991888375775292)
# ('HR', 0.00743119704464095)
# ('AR', 0.014450217300875591)

# %%
#make a single prediction
#features: ['HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR]
HS = 10
AS = 7
HST = 5
AST = 5
HF = 11
AF = 12
HC = 3
AC = 6
HY = 3
AY = 2
HR = 0
AR = 1
row = [[HS, AS, HST, AST, HF, AF, HC, AC, HY, AY, HR, AR]]
yhat = forest_model.predict(row)
yhat = float(yhat)
print(f'Home Team XG: {yhat}')
# Out:
# Home Team XG: 1.98

# %%
#Really weird, corners are hurting teams? Need to figure this out.
# Corner and goals are positively correlated
corr_matrix = epl.corr()
corr_matrix['FTHG'].sort_values(ascending = False)
# Out:
# FTHG    1.000000
# HST     0.446156
# HS      0.288352
# AR      0.072354
# HC      0.057204
# AY     -0.011191
# AF     -0.045542
# HF     -0.059840
# AC     -0.080303
# HR     -0.080648
# FTAG   -0.084583
# AST    -0.100444
# HY     -0.111800
# AS     -0.152125
# Name: FTHG, dtype: float64

# %%
# weigh shots more maybe?

# %%
def predict_home_goals_forest(HS, AS, HST, AST, HF, AF, HC, AC, HY, AY, HR, AR):
    box_score = [[HS, AS, HST, AST, HF, AF, HC, AC, HY, AY, HR, AR]]
    yhat = forest_model.predict(row)
    yhat = float(yhat)
    print(f'Home Team XG: {yhat}')
    return yhat
